# %%
import numpy as np
import os
import sys
import time
import random

# We use Sklearn libraries to run GP

from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import Matern, RBF, WhiteKernel,\
     ConstantKernel as C,\
     RationalQuadratic as RQ,\
     ExpSineSquared as ESS,\
     DotProduct as DP
from sklearn.metrics import mean_squared_error as mse
from sklearn.model_selection import train_test_split

'''
'Authors: Apurba Nandi, Joel M. Bowman, Paul Houston'
'Location: Emory University, Department of Chemistry, Atlanta, USA'
'Contact: apurba.nandi@emory.edy, jmbowma@emory.edu;'
'Date: May 8, 2020'
'Version: ML-Rate-Cons-V1.0'
'''

#----------------------------------
# FUNCTIONS
def pred_gp(gp,X):
#   gp --> trained GP model
#   X  --> Points to predict 
    y_pred, sigma = gp.predict(np.atleast_2d(X), return_std=True)
    return y_pred, sigma

#----------------------------------------------
#                 MAIN
#----------------------------------------------

start_time = time.time()

print ("\033[5;39;38m***********************************************************")
print ("--------Gaussian Process for Rate Constant Prediction---------")
print ("Authors: Apurba Nandi, Joel M. Bowman, Paul Houston")
print ("Location: Emory University, Department of Chemistry, Atlanta, USA")
print ("Contact: apurba.nandi@emory.edy, jmbowma@emory.edu;")
print ("Date: May 8, 2020")
print ("Version: ML-Rate-Cons-V1.0")
print ("**GP is performed from Sklearn Libraries. We gratly thankful to Rodrigo A. Vargas Hernandez and Roman V. Krems to provide their GP program which was used to fit potential energy surface.**")
print ("***********************************************************")

#------------------------------------------------------------

# File name specification and cluster specification to run GP.
#-------------------------------------------------------------
f_test_data = input("Please Enter the name of the data file for prediction: \n")
cluster_val = int(input("Which Cluster do you want: For Small-Chi cluster enter 1 or For Large-Chi cluster enter 2:  \n"))
#----------------------------------------------------------
# Begining of if statement. 
# This part is for Small-Chi cluster training and testing
#----------------------------------------------------------
if cluster_val==1:
    print ("Small-Chi cluster is in use")
    f_train_data = "Small_chi.dat"    # Small-Chi Cluster training data file
    f_train_out= "Small_chi_train.out"      # Output file for the training data
    f_test_out = "Small_chi_predict.out"  # Output file for the test data
    f_theta = "gp_theta.dat"                     # File contains Theta values
    f_alpha = "gp_alpha.dat"                     # File contains Alpha values
    gwd = os.getcwd() # ---> GENERAL WORKING DIRECTORY
    gwd = gwd + '/'
    os.chdir(gwd)
    print ("\033[5;35;38m------------------------------")
    print ("Data will be taken from: ", gwd)
    print ("Data in file: ", f_train_data)
    print ("GP prediction output in file: ", f_test_out)
    print ("------------------------------")
    #----------------------------------
    # READ DATA
    #  Read the training points from Small-Chi cluster data file
    if os.path.isfile(gwd + f_train_data):
        X = np.loadtxt(gwd + f_train_data, usecols=range(4))
        y = np.loadtxt(gwd + f_train_data, usecols=(4,))
        train_set = np.column_stack((X, y))
        N_training, N_dimension = X.shape
        d = N_dimension
    else: 
        print (" file " + f_data + " does not exist!!")
        sys.exit("Error message")
    if os.path.isfile(gwd + f_test_data):
        Z = np.loadtxt(gwd + f_test_data, usecols=range(4))
        test_set = np.column_stack((Z))
        N_test = Z.shape[0]
    else:
        print (" file " + f_test_data + " does not exist!!")
        sys.exit("Error message")
    print ("---------------------------------")
    print ("Training data:")
    print ("Number of dimensions: ", N_dimension )
    print ("Number of training points: ", N_training )
    print ("Test data:")
    print ("Number of test points: ", N_test )  
    print ("---------------------------------")
    print ("\033[2;39;38m***********************************************************")
    for i in range(N_test):
            if 0.16 < np.array(Z[i,0]) > 12.56 or 1.03 < np.array(Z[i,1]) > 3.51 or 0.71 < np.array(Z[i,2]) > 95.12 or 11.60 < np.array(Z[i,3]) > 89.30 :
                print ("\033[1;31;38m **Warning: Data is outside of the training data range. Test_Data:", i+1)
                
            else:
                print ("\033[2;32;38m **Test data is okay for prediction. Test_Data:", i+1)
        
    print ("\033[2;39;38m***********************************************************")
    print ("\033[2;34;38m---------------------------------")
    ck = C(1.0, (1e-2, 1e2))
    k = ck * RBF(length_scale=(1.0,1.0,1.0,1.0), length_scale_bounds=(1e-3, 1e+3)) # Range of length scale parameter for Small-Chi cluster. You can change this range.
    k = k + ck * WhiteKernel(noise_level=1e-5, noise_level_bounds=(1e-6, 1e-4))    # Range of sigma noise parameter for Small-Chi cluster. You can change this range.
    print (k)
    #---------------------------------
    # TRAIN GP MODEL WITH COORDINATES
    print ("Training GP model normal coordinates")
    gp = GaussianProcessRegressor(kernel=k,n_restarts_optimizer=20)
    gp.fit(np.atleast_2d(X), y)
    print("Learned kernel (GP): %s" % gp.kernel_)
    print("Log-marginal-likelihood (GP): %.3f" % gp.log_marginal_likelihood(gp.kernel_.theta))
    np.savetxt(gwd + f_theta, gp.kernel_.theta)
    np.savetxt(gwd + f_alpha, gp.alpha_)
    print ("Prediction with GP model")
    y_pred1, sigma1 = pred_gp(gp, X)
    ygp1 = np.column_stack((y, y_pred1, abs(y-y_pred1), sigma1)) #Printing on output file for Small-Chi training data: Training-chi, predicted-chi, absolute error and uncertainty.
    np.savetxt(gwd + f_train_out, ygp1)
    rmse = np.sqrt(mse(y, y_pred1))
    print ("Training RMSE = ", rmse)
    y_pred2, sigma2 = pred_gp(gp, Z)
    ygp2 = np.column_stack((Z, y_pred2, sigma2))                    #Printing on output file for Small-Chi test data: predicted-chi and uncertainty.
    np.savetxt(gwd + f_test_out, ygp2)
    print ("-------------------------")
    #----------------------------------
#---------------------------------------------------------- 
# This part is for Large-Chi cluster training and testing
#----------------------------------------------------------
if cluster_val==2:
        print ("Large-Chi cluster is in use")	
        f_train_data = "Large_chi.dat"     # Small-Chi Cluster training data file
        f_train_out= "Large_chi_train.out"       # Output file for the training data
        f_test_out = "Large_chi_predict.out"   # Output file for the test data
        f_theta = "gp_theta.dat"                      # File contains Theta values
        f_alpha = "gp_alpha.dat"                      # File contains Alpha values
        gwd = os.getcwd() # ---> GENERAL WORKING DIRECTORY
        gwd = gwd + '/'
        os.chdir(gwd)
        print ("\033[5;35;38m------------------------------")
        print ("data will be taken from: ", gwd)
        print ("data in file: ", f_train_data)
        print ("GP prediction output in file:", f_test_out)
        print ("------------------------------")
        #----------------------------------
        # READ DATA
        #  Read the training points from Large-Chi cluster data file
        if os.path.isfile(gwd + f_train_data):
                X = np.loadtxt(gwd + f_train_data, usecols=range(4))
                y = np.loadtxt(gwd + f_train_data, usecols=(4,))
                train_set = np.column_stack((X, y))
                N_training, N_dimension = X.shape
                d = N_dimension
        else:
                print (" file " + f_data + " does not exist!!")
                sys.exit("Error message")
        if os.path.isfile(gwd + f_test_data):
                Z = np.loadtxt(gwd + f_test_data, usecols=range(4))
                test_set = np.column_stack((Z))
                N_test = Z.shape[0]
        else:
                print (" file " + f_test_data + " does not exist!!")
                sys.exit("Error message")
        print ("---------------------------------")
        print ("Training data:")
        print ("Number of dimensions: ", N_dimension)
        print ("Number of training points: ", N_training)
        print ("Test data:")
        print ("Number of test points: ", N_test)
        print ("---------------------------------")
        print ("\033[2;39;38m***********************************************************")
        for i in range(N_test):
            if 5.27 < np.array(Z[i,0]) > 15.75 or 1.46 < np.array(Z[i,1]) > 3.51 or 1.46 < np.array(Z[i,2]) > 6.24 or 13.60 < np.array(Z[i,3]) > 89.30 :
                print ("\033[5;31;38m **Warning: Data is outside of the training data range. Test_Data:", i+1)
                
            else:
                print ("\033[5;32;38m **Test data is okay for prediction. Test_Data:", i+1)
        
        print ("\033[2;39;38m***********************************************************")
        print ("\033[2;34;38m---------------------------------")
        ck = C(1.0, (1e-2, 1e2))
        k = ck * RBF(length_scale=(1.0,1.0,1.0,1.0), length_scale_bounds=(1e-1, 1e+3))  # Range of length scale parameter for Small-Chi cluster. You can change this range.
        k = k + ck * WhiteKernel(noise_level=1e-1, noise_level_bounds=(1e-2, 1e-0))     # Range of sigma noise parameter for Small-Chi cluster. You can change this range.
        print (k)
        #--------------------------------
        # TRAIN GP MODEL WITH COORDINATES
        print ("Training GP model normal coordinates")
        gp = GaussianProcessRegressor(kernel=k,n_restarts_optimizer=20)
        gp.fit(np.atleast_2d(X), y)
        print("Learned kernel (GP): %s" % gp.kernel_)
        print("Log-marginal-likelihood (GP): %.3f" % gp.log_marginal_likelihood(gp.kernel_.theta))
        np.savetxt(gwd + f_theta, gp.kernel_.theta)
        np.savetxt(gwd + f_alpha, gp.alpha_)
        print ("Prediction with GP model")
        y_pred1, sigma1 = pred_gp(gp, X)
        ygp1 = np.column_stack((y, y_pred1, abs(y-y_pred1), sigma1))    #Printing on output file for Large-Chi training data: Training-chi, predicted-chi, absolute error and uncertainty.
        np.savetxt(gwd + f_train_out, ygp1)
        rmse = np.sqrt(mse(y, y_pred1))
        print ("Training RMSE = ", rmse)
        y_pred2, sigma2 = pred_gp(gp, Z)
        ygp2 = np.column_stack((Z, y_pred2, sigma2))                      #Printing on output file for Large-Chi test data: predicted-chi and uncertainty.
        np.savetxt(gwd + f_test_out, ygp2)
        #rmse = np.sqrt(mse(w, y_pred2))
        print ("-------------------------")
        #----------------------------------


print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# ***********************************************************
# --------Gaussian Process for Rate Constant Prediction---------
# Authors: Apurba Nandi, Joel M. Bowman, Paul Houston
# Location: Emory University, Department of Chemistry, Atlanta, USA
# Contact: apurba.nandi@emory.edy, jmbowma@emory.edu;
# Date: May 8, 2020
# Version: ML-Rate-Cons-V1.0
# **GP is performed from Sklearn Libraries. We gratly thankful to Rodrigo A. Vargas Hernandez and Roman V. Krems to provide their GP program which was used to fit potential energy surface.**
# ***********************************************************
# Please Enter the name of the data file for prediction:
# Small_chi.dat
# Which Cluster do you want: For Small-Chi cluster enter 1 or For Large-Chi cluster enter 2:
# 1
# Small-Chi cluster is in use
# ------------------------------
# Data will be taken from:  C:\Users\jeffr\Desktop\chi_rate_constant\misc\GPR_Chi\GPR_Chi/
# Data in file:  Small_chi.dat
# GP prediction output in file:  Small_chi_predict.out
# ------------------------------
# ---------------------------------
# Training data:
# Number of dimensions:  4
# Number of training points:  366
# Test data:
# Number of test points:  366
# ---------------------------------
# ***********************************************************
#  **Test data is okay for prediction. Test_Data: 1
#  **Test data is okay for prediction. Test_Data: 2
#  **Test data is okay for prediction. Test_Data: 3
#  **Test data is okay for prediction. Test_Data: 4
#  **Test data is okay for prediction. Test_Data: 5
#  **Test data is okay for prediction. Test_Data: 6
#  **Test data is okay for prediction. Test_Data: 7
#  **Test data is okay for prediction. Test_Data: 8
#  **Test data is okay for prediction. Test_Data: 9
#  **Test data is okay for prediction. Test_Data: 10
#  **Test data is okay for prediction. Test_Data: 11
#  **Test data is okay for prediction. Test_Data: 12
#  **Test data is okay for prediction. Test_Data: 13
#  **Test data is okay for prediction. Test_Data: 14
#  **Test data is okay for prediction. Test_Data: 15
#  **Warning: Data is outside of the training data range. Test_Data: 16
#  **Test data is okay for prediction. Test_Data: 17
#  **Test data is okay for prediction. Test_Data: 18
#  **Test data is okay for prediction. Test_Data: 19
#  **Test data is okay for prediction. Test_Data: 20
#  **Test data is okay for prediction. Test_Data: 21
#  **Test data is okay for prediction. Test_Data: 22
#  **Test data is okay for prediction. Test_Data: 23
#  **Test data is okay for prediction. Test_Data: 24
#  **Test data is okay for prediction. Test_Data: 25
#  **Test data is okay for prediction. Test_Data: 26
#  **Test data is okay for prediction. Test_Data: 27
#  **Test data is okay for prediction. Test_Data: 28
#  **Test data is okay for prediction. Test_Data: 29
#  **Test data is okay for prediction. Test_Data: 30
#  **Test data is okay for prediction. Test_Data: 31
#  **Test data is okay for prediction. Test_Data: 32
#  **Test data is okay for prediction. Test_Data: 33
#  **Test data is okay for prediction. Test_Data: 34
#  **Test data is okay for prediction. Test_Data: 35
#  **Test data is okay for prediction. Test_Data: 36
#  **Test data is okay for prediction. Test_Data: 37
#  **Test data is okay for prediction. Test_Data: 38
#  **Test data is okay for prediction. Test_Data: 39
#  **Test data is okay for prediction. Test_Data: 40
#  **Test data is okay for prediction. Test_Data: 41
#  **Test data is okay for prediction. Test_Data: 42
#  **Test data is okay for prediction. Test_Data: 43
#  **Test data is okay for prediction. Test_Data: 44
#  **Test data is okay for prediction. Test_Data: 45
#  **Test data is okay for prediction. Test_Data: 46
#  **Test data is okay for prediction. Test_Data: 47
#  **Test data is okay for prediction. Test_Data: 48
#  **Test data is okay for prediction. Test_Data: 49
#  **Test data is okay for prediction. Test_Data: 50
#  **Test data is okay for prediction. Test_Data: 51
#  **Test data is okay for prediction. Test_Data: 52
#  **Test data is okay for prediction. Test_Data: 53
#  **Test data is okay for prediction. Test_Data: 54
#  **Test data is okay for prediction. Test_Data: 55
#  **Test data is okay for prediction. Test_Data: 56
#  **Test data is okay for prediction. Test_Data: 57
#  **Test data is okay for prediction. Test_Data: 58
#  **Test data is okay for prediction. Test_Data: 59
#  **Test data is okay for prediction. Test_Data: 60
#  **Test data is okay for prediction. Test_Data: 61
#  **Test data is okay for prediction. Test_Data: 62
#  **Test data is okay for prediction. Test_Data: 63
#  **Test data is okay for prediction. Test_Data: 64
#  **Test data is okay for prediction. Test_Data: 65
#  **Test data is okay for prediction. Test_Data: 66
#  **Test data is okay for prediction. Test_Data: 67
#  **Test data is okay for prediction. Test_Data: 68
#  **Test data is okay for prediction. Test_Data: 69
#  **Test data is okay for prediction. Test_Data: 70
#  **Test data is okay for prediction. Test_Data: 71
#  **Test data is okay for prediction. Test_Data: 72
#  **Test data is okay for prediction. Test_Data: 73
#  **Test data is okay for prediction. Test_Data: 74
#  **Test data is okay for prediction. Test_Data: 75
#  **Test data is okay for prediction. Test_Data: 76
#  **Test data is okay for prediction. Test_Data: 77
#  **Test data is okay for prediction. Test_Data: 78
#  **Test data is okay for prediction. Test_Data: 79
#  **Test data is okay for prediction. Test_Data: 80
#  **Test data is okay for prediction. Test_Data: 81
#  **Test data is okay for prediction. Test_Data: 82
#  **Test data is okay for prediction. Test_Data: 83
#  **Test data is okay for prediction. Test_Data: 84
#  **Test data is okay for prediction. Test_Data: 85
#  **Test data is okay for prediction. Test_Data: 86
#  **Test data is okay for prediction. Test_Data: 87
#  **Test data is okay for prediction. Test_Data: 88
#  **Test data is okay for prediction. Test_Data: 89
#  **Test data is okay for prediction. Test_Data: 90
#  **Test data is okay for prediction. Test_Data: 91
#  **Test data is okay for prediction. Test_Data: 92
#  **Test data is okay for prediction. Test_Data: 93
#  **Test data is okay for prediction. Test_Data: 94
#  **Test data is okay for prediction. Test_Data: 95
#  **Test data is okay for prediction. Test_Data: 96
#  **Test data is okay for prediction. Test_Data: 97
#  **Test data is okay for prediction. Test_Data: 98
#  **Test data is okay for prediction. Test_Data: 99
#  **Test data is okay for prediction. Test_Data: 100
#  **Test data is okay for prediction. Test_Data: 101
#  **Test data is okay for prediction. Test_Data: 102
#  **Test data is okay for prediction. Test_Data: 103
#  **Test data is okay for prediction. Test_Data: 104
#  **Test data is okay for prediction. Test_Data: 105
#  **Test data is okay for prediction. Test_Data: 106
#  **Test data is okay for prediction. Test_Data: 107
#  **Test data is okay for prediction. Test_Data: 108
#  **Test data is okay for prediction. Test_Data: 109
#  **Test data is okay for prediction. Test_Data: 110
#  **Test data is okay for prediction. Test_Data: 111
#  **Test data is okay for prediction. Test_Data: 112
#  **Test data is okay for prediction. Test_Data: 113
#  **Test data is okay for prediction. Test_Data: 114
#  **Test data is okay for prediction. Test_Data: 115
#  **Test data is okay for prediction. Test_Data: 116
#  **Test data is okay for prediction. Test_Data: 117
#  **Test data is okay for prediction. Test_Data: 118
#  **Test data is okay for prediction. Test_Data: 119
#  **Test data is okay for prediction. Test_Data: 120
#  **Test data is okay for prediction. Test_Data: 121
#  **Test data is okay for prediction. Test_Data: 122
#  **Test data is okay for prediction. Test_Data: 123
#  **Test data is okay for prediction. Test_Data: 124
#  **Test data is okay for prediction. Test_Data: 125
#  **Test data is okay for prediction. Test_Data: 126
#  **Test data is okay for prediction. Test_Data: 127
#  **Test data is okay for prediction. Test_Data: 128
#  **Test data is okay for prediction. Test_Data: 129
#  **Test data is okay for prediction. Test_Data: 130
#  **Test data is okay for prediction. Test_Data: 131
#  **Test data is okay for prediction. Test_Data: 132
#  **Test data is okay for prediction. Test_Data: 133
#  **Test data is okay for prediction. Test_Data: 134
#  **Test data is okay for prediction. Test_Data: 135
#  **Test data is okay for prediction. Test_Data: 136
#  **Test data is okay for prediction. Test_Data: 137
#  **Test data is okay for prediction. Test_Data: 138
#  **Test data is okay for prediction. Test_Data: 139
#  **Test data is okay for prediction. Test_Data: 140
#  **Test data is okay for prediction. Test_Data: 141
#  **Test data is okay for prediction. Test_Data: 142
#  **Test data is okay for prediction. Test_Data: 143
#  **Test data is okay for prediction. Test_Data: 144
#  **Test data is okay for prediction. Test_Data: 145
#  **Test data is okay for prediction. Test_Data: 146
#  **Test data is okay for prediction. Test_Data: 147
#  **Test data is okay for prediction. Test_Data: 148
#  **Test data is okay for prediction. Test_Data: 149
#  **Test data is okay for prediction. Test_Data: 150
#  **Test data is okay for prediction. Test_Data: 151
#  **Test data is okay for prediction. Test_Data: 152
#  **Test data is okay for prediction. Test_Data: 153
#  **Test data is okay for prediction. Test_Data: 154
#  **Test data is okay for prediction. Test_Data: 155
#  **Test data is okay for prediction. Test_Data: 156
#  **Test data is okay for prediction. Test_Data: 157
#  **Test data is okay for prediction. Test_Data: 158
#  **Test data is okay for prediction. Test_Data: 159
#  **Test data is okay for prediction. Test_Data: 160
#  **Test data is okay for prediction. Test_Data: 161
#  **Test data is okay for prediction. Test_Data: 162
#  **Test data is okay for prediction. Test_Data: 163
#  **Test data is okay for prediction. Test_Data: 164
#  **Test data is okay for prediction. Test_Data: 165
#  **Test data is okay for prediction. Test_Data: 166
#  **Test data is okay for prediction. Test_Data: 167
#  **Test data is okay for prediction. Test_Data: 168
#  **Test data is okay for prediction. Test_Data: 169
#  **Test data is okay for prediction. Test_Data: 170
#  **Test data is okay for prediction. Test_Data: 171
#  **Test data is okay for prediction. Test_Data: 172
#  **Test data is okay for prediction. Test_Data: 173
#  **Test data is okay for prediction. Test_Data: 174
#  **Test data is okay for prediction. Test_Data: 175
#  **Test data is okay for prediction. Test_Data: 176
#  **Test data is okay for prediction. Test_Data: 177
#  **Test data is okay for prediction. Test_Data: 178
#  **Test data is okay for prediction. Test_Data: 179
#  **Test data is okay for prediction. Test_Data: 180
#  **Test data is okay for prediction. Test_Data: 181
#  **Test data is okay for prediction. Test_Data: 182
#  **Test data is okay for prediction. Test_Data: 183
#  **Test data is okay for prediction. Test_Data: 184
#  **Test data is okay for prediction. Test_Data: 185
#  **Test data is okay for prediction. Test_Data: 186
#  **Test data is okay for prediction. Test_Data: 187
#  **Test data is okay for prediction. Test_Data: 188
#  **Test data is okay for prediction. Test_Data: 189
#  **Test data is okay for prediction. Test_Data: 190
#  **Test data is okay for prediction. Test_Data: 191
#  **Test data is okay for prediction. Test_Data: 192
#  **Test data is okay for prediction. Test_Data: 193
#  **Test data is okay for prediction. Test_Data: 194
#  **Test data is okay for prediction. Test_Data: 195
#  **Test data is okay for prediction. Test_Data: 196
#  **Test data is okay for prediction. Test_Data: 197
#  **Test data is okay for prediction. Test_Data: 198
#  **Test data is okay for prediction. Test_Data: 199
#  **Test data is okay for prediction. Test_Data: 200
#  **Test data is okay for prediction. Test_Data: 201
#  **Test data is okay for prediction. Test_Data: 202
#  **Test data is okay for prediction. Test_Data: 203
#  **Test data is okay for prediction. Test_Data: 204
#  **Test data is okay for prediction. Test_Data: 205
#  **Test data is okay for prediction. Test_Data: 206
#  **Test data is okay for prediction. Test_Data: 207
#  **Test data is okay for prediction. Test_Data: 208
#  **Test data is okay for prediction. Test_Data: 209
#  **Test data is okay for prediction. Test_Data: 210
#  **Test data is okay for prediction. Test_Data: 211
#  **Test data is okay for prediction. Test_Data: 212
#  **Test data is okay for prediction. Test_Data: 213
#  **Test data is okay for prediction. Test_Data: 214
#  **Test data is okay for prediction. Test_Data: 215
#  **Test data is okay for prediction. Test_Data: 216
#  **Test data is okay for prediction. Test_Data: 217
#  **Test data is okay for prediction. Test_Data: 218
#  **Test data is okay for prediction. Test_Data: 219
#  **Test data is okay for prediction. Test_Data: 220
#  **Test data is okay for prediction. Test_Data: 221
#  **Test data is okay for prediction. Test_Data: 222
#  **Test data is okay for prediction. Test_Data: 223
#  **Test data is okay for prediction. Test_Data: 224
#  **Test data is okay for prediction. Test_Data: 225
#  **Test data is okay for prediction. Test_Data: 226
#  **Test data is okay for prediction. Test_Data: 227
#  **Test data is okay for prediction. Test_Data: 228
#  **Test data is okay for prediction. Test_Data: 229
#  **Test data is okay for prediction. Test_Data: 230
#  **Test data is okay for prediction. Test_Data: 231
#  **Test data is okay for prediction. Test_Data: 232
#  **Test data is okay for prediction. Test_Data: 233
#  **Test data is okay for prediction. Test_Data: 234
#  **Test data is okay for prediction. Test_Data: 235
#  **Test data is okay for prediction. Test_Data: 236
#  **Test data is okay for prediction. Test_Data: 237
#  **Test data is okay for prediction. Test_Data: 238
#  **Test data is okay for prediction. Test_Data: 239
#  **Test data is okay for prediction. Test_Data: 240
#  **Test data is okay for prediction. Test_Data: 241
#  **Test data is okay for prediction. Test_Data: 242
#  **Test data is okay for prediction. Test_Data: 243
#  **Test data is okay for prediction. Test_Data: 244
#  **Test data is okay for prediction. Test_Data: 245
#  **Test data is okay for prediction. Test_Data: 246
#  **Test data is okay for prediction. Test_Data: 247
#  **Test data is okay for prediction. Test_Data: 248
#  **Test data is okay for prediction. Test_Data: 249
#  **Test data is okay for prediction. Test_Data: 250
#  **Test data is okay for prediction. Test_Data: 251
#  **Test data is okay for prediction. Test_Data: 252
#  **Test data is okay for prediction. Test_Data: 253
#  **Test data is okay for prediction. Test_Data: 254
#  **Test data is okay for prediction. Test_Data: 255
#  **Test data is okay for prediction. Test_Data: 256
#  **Test data is okay for prediction. Test_Data: 257
#  **Test data is okay for prediction. Test_Data: 258
#  **Test data is okay for prediction. Test_Data: 259
#  **Test data is okay for prediction. Test_Data: 260
#  **Test data is okay for prediction. Test_Data: 261
#  **Test data is okay for prediction. Test_Data: 262
#  **Test data is okay for prediction. Test_Data: 263
#  **Test data is okay for prediction. Test_Data: 264
#  **Test data is okay for prediction. Test_Data: 265
#  **Test data is okay for prediction. Test_Data: 266
#  **Test data is okay for prediction. Test_Data: 267
#  **Test data is okay for prediction. Test_Data: 268
#  **Test data is okay for prediction. Test_Data: 269
#  **Test data is okay for prediction. Test_Data: 270
#  **Test data is okay for prediction. Test_Data: 271
#  **Test data is okay for prediction. Test_Data: 272
#  **Test data is okay for prediction. Test_Data: 273
#  **Test data is okay for prediction. Test_Data: 274
#  **Test data is okay for prediction. Test_Data: 275
#  **Test data is okay for prediction. Test_Data: 276
#  **Test data is okay for prediction. Test_Data: 277
#  **Test data is okay for prediction. Test_Data: 278
#  **Test data is okay for prediction. Test_Data: 279
#  **Test data is okay for prediction. Test_Data: 280
#  **Test data is okay for prediction. Test_Data: 281
#  **Test data is okay for prediction. Test_Data: 282
#  **Test data is okay for prediction. Test_Data: 283
#  **Test data is okay for prediction. Test_Data: 284
#  **Test data is okay for prediction. Test_Data: 285
#  **Test data is okay for prediction. Test_Data: 286
#  **Test data is okay for prediction. Test_Data: 287
#  **Test data is okay for prediction. Test_Data: 288
#  **Test data is okay for prediction. Test_Data: 289
#  **Test data is okay for prediction. Test_Data: 290
#  **Test data is okay for prediction. Test_Data: 291
#  **Test data is okay for prediction. Test_Data: 292
#  **Test data is okay for prediction. Test_Data: 293
#  **Test data is okay for prediction. Test_Data: 294
#  **Test data is okay for prediction. Test_Data: 295
#  **Test data is okay for prediction. Test_Data: 296
#  **Test data is okay for prediction. Test_Data: 297
#  **Test data is okay for prediction. Test_Data: 298
#  **Test data is okay for prediction. Test_Data: 299
#  **Test data is okay for prediction. Test_Data: 300
#  **Test data is okay for prediction. Test_Data: 301
#  **Test data is okay for prediction. Test_Data: 302
#  **Test data is okay for prediction. Test_Data: 303
#  **Test data is okay for prediction. Test_Data: 304
#  **Test data is okay for prediction. Test_Data: 305
#  **Test data is okay for prediction. Test_Data: 306
#  **Test data is okay for prediction. Test_Data: 307
#  **Test data is okay for prediction. Test_Data: 308
#  **Test data is okay for prediction. Test_Data: 309
#  **Test data is okay for prediction. Test_Data: 310
#  **Test data is okay for prediction. Test_Data: 311
#  **Test data is okay for prediction. Test_Data: 312
#  **Test data is okay for prediction. Test_Data: 313
#  **Test data is okay for prediction. Test_Data: 314
#  **Test data is okay for prediction. Test_Data: 315
#  **Test data is okay for prediction. Test_Data: 316
#  **Test data is okay for prediction. Test_Data: 317
#  **Test data is okay for prediction. Test_Data: 318
#  **Test data is okay for prediction. Test_Data: 319
#  **Test data is okay for prediction. Test_Data: 320
#  **Test data is okay for prediction. Test_Data: 321
#  **Test data is okay for prediction. Test_Data: 322
#  **Test data is okay for prediction. Test_Data: 323
#  **Test data is okay for prediction. Test_Data: 324
#  **Test data is okay for prediction. Test_Data: 325
#  **Test data is okay for prediction. Test_Data: 326
#  **Test data is okay for prediction. Test_Data: 327
#  **Test data is okay for prediction. Test_Data: 328
#  **Test data is okay for prediction. Test_Data: 329
#  **Test data is okay for prediction. Test_Data: 330
#  **Test data is okay for prediction. Test_Data: 331
#  **Test data is okay for prediction. Test_Data: 332
#  **Test data is okay for prediction. Test_Data: 333
#  **Test data is okay for prediction. Test_Data: 334
#  **Test data is okay for prediction. Test_Data: 335
#  **Test data is okay for prediction. Test_Data: 336
#  **Test data is okay for prediction. Test_Data: 337
#  **Test data is okay for prediction. Test_Data: 338
#  **Test data is okay for prediction. Test_Data: 339
#  **Test data is okay for prediction. Test_Data: 340
#  **Test data is okay for prediction. Test_Data: 341
#  **Test data is okay for prediction. Test_Data: 342
#  **Test data is okay for prediction. Test_Data: 343
#  **Test data is okay for prediction. Test_Data: 344
#  **Test data is okay for prediction. Test_Data: 345
#  **Test data is okay for prediction. Test_Data: 346
#  **Test data is okay for prediction. Test_Data: 347
#  **Test data is okay for prediction. Test_Data: 348
#  **Test data is okay for prediction. Test_Data: 349
#  **Test data is okay for prediction. Test_Data: 350
#  **Test data is okay for prediction. Test_Data: 351
#  **Test data is okay for prediction. Test_Data: 352
#  **Test data is okay for prediction. Test_Data: 353
#  **Test data is okay for prediction. Test_Data: 354
#  **Test data is okay for prediction. Test_Data: 355
#  **Test data is okay for prediction. Test_Data: 356
#  **Test data is okay for prediction. Test_Data: 357
#  **Test data is okay for prediction. Test_Data: 358
#  **Test data is okay for prediction. Test_Data: 359
#  **Test data is okay for prediction. Test_Data: 360
#  **Test data is okay for prediction. Test_Data: 361
#  **Test data is okay for prediction. Test_Data: 362
#  **Test data is okay for prediction. Test_Data: 363
#  **Test data is okay for prediction. Test_Data: 364
#  **Test data is okay for prediction. Test_Data: 365
#  **Test data is okay for prediction. Test_Data: 366
# ***********************************************************
# ---------------------------------
# 1**2 * RBF(length_scale=[1, 1, 1, 1]) + 1**2 * WhiteKernel(noise_level=1e-05)
# Training GP model normal coordinates
# Learned kernel (GP): 1.35**2 * RBF(length_scale=[4.18, 0.0482, 115, 29]) + 10**2 * WhiteKernel(noise_level=0.0001)
# Log-marginal-likelihood (GP): -253.605
# Prediction with GP model
# Training RMSE =  0.142813207897965
# -------------------------
# --- 77.76627254486084 seconds ---
# C:\Users\jeffr\anaconda3\lib\site-packages\sklearn\gaussian_process\kernels.py:430: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__k1__constant_value is close to the specified upper bound 100.0. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
# C:\Users\jeffr\anaconda3\lib\site-packages\sklearn\gaussian_process\kernels.py:430: ConvergenceWarning: The optimal value found for dimension 0 of parameter k2__k2__noise_level is close to the specified upper bound 0.0001. Increasing the bound and calling fit again may find a better value.
#   warnings.warn(
